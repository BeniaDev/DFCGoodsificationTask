# %% [markdown]
# ## Загрузжаем нужные библиотеки

# %%
# !git clone https://github.com/huggingface/transformers
# !pip install datasets
# !cd transformers; python setup.py install
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 72060, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 72060 (delta 24), reused 43 (delta 11), pack-reused 71972
# Receiving objects: 100% (72060/72060), 54.81 MiB | 28.90 MiB/s, done.
# Resolving deltas: 100% (51156/51156), done.
# ...
#      |████████████████████████████████| 225kB 16.3MB/s
# ...
#      |████████████████████████████████| 245kB 33.6MB/s
# ...
#      |████████████████████████████████| 112kB 52.8MB/s
# ...
# running install
# running bdist_egg
# running egg_info
# creating src/transformers.egg-info
# writing src/transformers.egg-info/PKG-INFO
# writing dependency_links to src/transformers.egg-info/dependency_links.txt
# writing entry points to src/transformers.egg-info/entry_points.txt
# writing requirements to src/transformers.egg-info/requires.txt
# writing top-level names to src/transformers.egg-info/top_level.txt
# ...

# %%
import random, torch
SEED = 42

random.seed(SEED)
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if device == 'cpu':
    print('cpu')
else:
    n_gpu = torch.cuda.device_count()
    print(torch.cuda.get_device_name(0))
# Out:
# Tesla T4

# %%
DATA_PATH_CLOUD = '/content/gdrive/MyDrive/DS/DFC/data/'

# mounting folder from google drive         
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import re
import string

import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score, train_test_split

# %%
# Подготовка данных

# %%
# %cd /content/transformers/examples/pytorch/language-modeling/
# Out:
# /content/transformers/examples/pytorch/language-modeling

# %%
# !ls -la $DATA_PATH_CLOUD
# Out:
# total 1281098
# -rw------- 1 root root        318 May  3 14:12 categories.csv
# -rw------- 1 root root   11086425 May  6 20:01 clean_mean_entity_data.csv
# -rw------- 1 root root 1107938448 Mar  8 10:15 data_fusion_train.parquet
# -rw------- 1 root root    5370657 May  6 19:13 item_name_100k.txt
# -rw------- 1 root root  181661438 May  6 19:13 item_name.txt
# drwx------ 2 root root       4096 Apr 26 15:05 mlm1500000
# drwx------ 2 root root       4096 Mar  8 10:26 Task1
# drwx------ 2 root root       4096 Mar  8 10:26 Task2
# -rw------- 1 root root    4013468 May  3 14:07 train_data.csv
# -rw------- 1 root root    1759349 Mar 18 15:14 work_df.parquet.gzip

# %% [markdown]
# # Дообучение DistliBERT на задаче masked language modeling

# %%
# !python run_mlm.py --model_name_or_path distilbert-base-multilingual-cased --model_type distilbert --train_file $DATA_PATH_CLOUD/mlm1500000/train.txt --validation_file $DATA_PATH_CLOUD/mlm1500000/test.txt --do_train --do_eval --output_dir $DATA_PATH_CLOUD/mlm1500000 --overwrite_output_dir
# Out:
# 2021-05-09 06:24:31.717010: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 05/09/2021 06:24:33 - WARNING - __main__ -   Process rank: -1, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# ...
